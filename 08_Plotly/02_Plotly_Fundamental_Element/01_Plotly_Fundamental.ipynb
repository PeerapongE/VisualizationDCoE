# %% [markdown]
# ## Interactive Plot: Plotly
#
# https://plot.ly/python/line-and-scatter/

# %% [markdown]
# ### Basic Scatter Plot

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import pandas as pd
pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('tips.csv')
df.head()

# %% [markdown]
# ### 1. Basic Plot only

# %%
# specify the trace (graph object)

trace0 = go.Scatter(x = df['total_bill'], # x data
                    y = df['tip'], # y data
                    mode = 'markers', #, default is line to plot scatter plot without line: lines, lines+markers , markers
                   )

data = [trace0]

# %%
# prepare figure by using go.Figure(data, layout)
fig = go.Figure(data = data)

# %%
# plotting
pyo.iplot(fig)

# %% [markdown]
# ### 2. Plotting with layout

# %%
 marker = dict(size = 10,color = 'rgba(152, 0, 0, .8)')
marker

# %%
# specify the trace (graph object)

trace0 = go.Scatter(x      = df['total_bill'], # x data
                    y      = df['tip'], # y data
                    mode   = 'markers', #, default is line to plot scatter plot without line: lines, lines+markers , markers
                    marker = {'color':'red','size':10} # set marker style
                   )

data = [trace0]

# %%
# specify layout information

layout = go.Layout(title = 'This is Basic Plotly Scatter Plot', # Graph title
                   xaxis = {'title': 'Total Bill'}, # x-axis label
                   yaxis = {'title': 'Tips'}, # y-axis label
                   hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# prepare figure by using go.Figure(data, layout)
fig = go.Figure(data = data, layout=layout)

# %%
# plotting
pyo.iplot(fig)

# %% [markdown]
# ### 3. Plot with multiple dataset

# %%
# add two trace to the data list

trace_lunch  = go.Scatter(x = df[df['time'] == 'Lunch']['total_bill'],
                          y = df[df['time'] == 'Lunch']['tip'],
                          mode = 'markers', # to plot scatter plot without line
                          name = 'lunch'
                         )

trace_dinner = go.Scatter(x = df[df['time'] == 'Dinner']['total_bill'],
                          y = df[df['time'] == 'Dinner']['tip'],
                          mode = 'markers', # to plot scatter plot without line
                          name = 'dinner'
                         )


data = [trace_lunch, trace_dinner]

# %%
layout = go.Layout(title = 'This is Basic Plotly Scatter Plot', # Graph title
                   xaxis = {'title': 'Total Bill'}, # x-axis label
                   yaxis = {'title': 'Tips'}, # y-axis label
                   hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
fig = go.Figure(data   = data,
                layout = layout
               )

# Plot offline
pyo.iplot(fig)

# %% [markdown]
# ### Exercise
#
# Plot ความสัมพันธ์ของ เวลาในการเล่นเฉลี่ย และ คะแนนที่ทำได้ โดยใช้ plotly
# * x = scoreMPG
# * y = scorePPG

# %%
NBA_df = pd.read_excel('Data_NBA_Player_trim.xlsx')
NBA_df.head()
# Out:
#    ID firstName  lastName playPosition      team  Height  Weight        born  \
# 0   1    Quincy       Acy            F      Nets    2.01   108.9  10/06/1990
# 1   2    Steven     Adams            C   Thunder    2.13   115.7  07/20/1993
# 2   3     Arron   Afflalo            G     Magic    1.96    95.3  10/15/1985
# 3   4    Alexis    Ajinca            C  Pelicans    2.18   112.5  05/06/1988
# 4   5  LaMarcus  Aldridge            F     Spurs    2.11   117.9  07/19/1985
#
#    age                   town  debut  yearInNBA  scoreMPG  scoreFGpct  \
# 0   27                 Baylor   2012          6      16.1        44.7
# 1   25             Pittsburgh   2013          5      25.5        58.6
# 2   32                   UCLA   2007         11      27.3        45.0
# 3   30  Saint Etienne, France   2008          7      13.3        50.3
# 4   33                  Texas   2006         12      34.6        48.9
#
#    scoreP3pct  scoreFTpct  scorePPG  scoreRPG  scoreAPG  scoreBPG
# 0        35.6        76.1       5.0       3.5       0.6       0.4
# 1         0.0        56.8       8.8       6.9       0.9       1.0
# 2        38.6        82.5      10.8       2.9       1.8       0.2
# 3        28.6        79.7       5.3       3.9       0.5       0.6
# 4        28.8        80.6      19.4       8.3       1.9       1.1

# %%
# prepare data
trace0 = go.Scatter(x = xxxx, # x data
                    y = xxxx, # y data
                    mode = xxxx, #, default is line to plot scatter plot without line: lines, lines+markers , markers
                   )

data = [trace0]

# %%
# prepare layout
layout = go.Layout(title = xxxxxx, # Graph title
                   xaxis = {'title': xxxxx}, # x-axis label
                   yaxis = {'title': xxxxxx}, # y-axis label
                   hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# create figure object
fig = go.Figure(data   = xxxx,
                layout = xxxx)

# %%
# plot
pyo.iplot(xxxx)

# %% [markdown]
# ### Solution

# %%
# specify the trace (graph object)

trace0 = go.Scatter(x = NBA_df['scoreMPG'], # x data
                    y = NBA_df['scorePPG'], # y data
                    mode = 'markers', #, default is line to plot scatter plot without line: lines, lines+markers , markers
                   )

data = [trace0]

# %%
# specify layout information

layout = go.Layout(title = 'Relationship between minute and point', # Graph title
                   xaxis = {'title': 'Minute Per Game'}, # x-axis label
                   yaxis = {'title': 'Point Per Game'}, # y-axis label
                   hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# prepare figure by using go.Figure(data, layout)
fig = go.Figure(data = data, layout=layout)

# %%
# plotting
pyo.iplot(fig)
# Out:
# <div>
#
#
#             <div id="24e0b3cf-9557-4686-894a-1d74543e62ce" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("24e0b3cf-9557-4686-894a-1d74543e62ce")) {
#                     Plotly.newPlot(
#                         '24e0b3cf-9557-4686-894a-1d74543e62ce',
#                         [{"mode": "markers", "type": "scatter", "uid": "788f70b5-5bdf-443d-8fce-f21f89d2fcbb", "x": [16.1, 25.5, 27.3, 13.3, 34.6, 20.0, 5.9, 24.8, 14.2, 17.9, 26.4, 2.6, 32.7, 35.9, 20.0, 29.5, 17.8, 19.6, 23.6, 14.0, 13.5, 15.3, 12.1, 34.2, 19.7, 30.4, 22.8, 31.6, 21.4, 15.0, 20.0, 33.9, 8.9, 23.4, 23.3, 12.9, 28.5, 13.8, 20.9, 15.1, 27.7, 32.2, 20.4, 28.4, 3.2, 23.3, 27.8, 20.8, 28.6, 17.9, 18.6, 23.6, 12.6, 14.4, 4.8, 16.1, 24.4, 21.0, 32.8, 14.2, 27.2, 30.8, 24.0, 27.5, 31.4, 15.2, 20.7, 22.8, 26.7, 28.3, 31.1, 21.2, 27.6, 24.1, 29.5, 32.5, 12.6, 19.7, 8.0, 32.4,
}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     )
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ### 4 Add regression line
#
# #### Add regression
# https://plot.ly/scikit-learn/plot-ols/
#
#
# #### Add legend
#
# https://plot.ly/python/legend/

# %%
# import sklearn
from sklearn import linear_model

# %%
# create model
regr = linear_model.LinearRegression()

# %%
# prepare data
x_data = NBA_df['scoreMPG'].values.reshape(-1,1)  # x value, reshape a bit to fit 2D format of sklearn
y_data = NBA_df['scorePPG']

# %%
# fit the model
regr.fit(x_data, y_data)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# use model for prediction
y_regress = regr.predict(x_data)
y_regress
# Out:
# array([ 5.82347521, 11.2777588 , 12.32219609,  4.19879499, 16.55796952,
#         8.08642266, -0.09500274, 10.87158875,  4.72101363,  6.86791249,
#        11.79997745, -2.00980442, 15.45550794, 17.31228534,  8.08642266,
#        13.59873055,  6.8098882 ,  7.85432548, 10.17529723,  4.60496504,
#         4.31484357,  5.35928086,  3.50250346, 16.32587234,  7.91234978,
#        14.12094919,  9.71110288, 14.81724071,  8.89876277,  5.18520798,
#         8.08642266, 16.15179946,  1.64572607, 10.05924864, 10.00122435,
#         3.96669781, 13.01848761,  4.48891646,  8.6086413 ,  5.24323227,
#        12.55429326, 15.16538647,  8.31851983, 12.96046332, -1.66165866,
#        10.00122435, 12.61231756,  8.55061701, 13.0765119 ,  6.86791249,
#         7.27408255, 10.17529723,  3.79262493,  4.83706222, -0.73326997,
#         5.82347521, 10.63949157,  8.66666559, 15.51353223,  4.72101363,
#        12.26417179, 14.35304636, 10.4073944 , 12.43824468, 14.70119212,
#         5.30125657,  8.49259271,  9.71110288, 11.97405033, 12.90243902,
#        14.52711924,  8.78271418, 12.49626897, 10.46541869, 13.59873055,
#        15.33945935,  3.79262493,  7.91234978,  1.12350743, 15.28143506,
#        13.54070625, 10.63949157,  5.82347521, 13.83082772, 10.23332152,
#         8.89876277,  9.94320005, 16.44192093,  5.53335374, 16.67401811,
#         3.44447917,  8.43456842,  6.22964526,  5.24323227,  6.8098882 ,
#         9.18888423, 16.61599381, 16.26784805,  3.03830912, 10.69751587,
#         9.82715146,  2.74818765,  3.67657635, -2.64807165, 12.72836614,
#        14.12094919, 10.05924864,  9.24690853, 18.00857686,  1.29758031,
#         8.66666559, 13.1345362 ,  8.31851983,  2.57411477, 15.10736218,
#        10.92961304, 11.62590457,  1.76177466, 14.0629249 , 12.26417179,
#         5.47532945, 12.26417179, 12.55429326,  9.71110288,  6.92593679,
#        14.58514354,  9.59505429, 16.03575088, 16.20982376, 16.55796952,
#        15.861678  , -0.15302703,  3.96669781, 11.62590457, 11.21973451,
#        12.72836614, 11.62590457, 15.74562941, 11.74195315,  4.48891646,
#         9.18888423,  7.33210684, 11.04566163, 12.55429326,  7.91234978,
#         9.4790057 , 14.0629249 , 16.79006669, -0.90734285, 10.98763734,
#        16.09377517,  9.82715146,  5.64940233, 10.98763734, 12.96046332,
#         7.79630119,  9.18888423,  6.17162097, 13.65675484,  9.94320005,
#        11.21973451,  4.37286787, 14.64316783,  8.31851983,  5.30125657,
#        13.77280343, 16.49994523, 13.1345362 , 16.15179946, 12.96046332,
#        17.31228534,  1.81979895, 12.09009891,  4.14077069,  4.37286787,
#        16.44192093, 12.84441473,  1.18153172,  8.37654412, 12.03207462,
#        17.48635822,  7.27408255, 10.63949157, 13.0765119 ,  6.28766956,
#        12.55429326,  6.40371814,  1.4136289 ,  9.76912717, 14.29502207,
#         9.53703   ,  6.69383961])

# %%
# specify the trace (graph object)

# historical data
trace_hist = go.Scatter(x = NBA_df['scoreMPG'], # x data
                        y = NBA_df['scorePPG'], # y data
                        mode = 'markers', #, default is line to plot scatter plot without line: lines, lines+markers , markers
                        name = 'Historical data'
                       )

# regression data
trace_regr = go.Scatter(x = NBA_df['scoreMPG'], # x data
                        y = y_regress, # y data
                        mode = 'lines', #, default is line to plot scatter plot without line: lines, lines+markers , markers
                        name = 'Regression trend'
                       )

data = [trace_hist, trace_regr]

# %%
# specify layout information

layout = go.Layout(title = 'Relationship between minute and point', # Graph title
                   xaxis = {'title': 'Minute Per Game'}, # x-axis label
                   yaxis = {'title': 'Point Per Game'}, # y-axis label
                   hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# prepare figure by using go.Figure(data, layout)
fig = go.Figure(data = data, layout=layout)

# %%
# plotting
pyo.iplot(fig)
# Out:
# <div>
#
#
#             <div id="1c0c6a1a-b15c-4e75-bde7-d201b92a4ba6" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1c0c6a1a-b15c-4e75-bde7-d201b92a4ba6")) {
#                     Plotly.newPlot(
#                         '1c0c6a1a-b15c-4e75-bde7-d201b92a4ba6',
#                         [{"mode": "markers", "name": "historical data", "type": "scatter", "uid": "bfd37b8b-231f-4631-9b2f-349403d1265b", "x": [16.1, 25.5, 27.3, 13.3, 34.6, 20.0, 5.9, 24.8, 14.2, 17.9, 26.4, 2.6, 32.7, 35.9, 20.0, 29.5, 17.8, 19.6, 23.6, 14.0, 13.5, 15.3, 12.1, 34.2, 19.7, 30.4, 22.8, 31.6, 21.4, 15.0, 20.0, 33.9, 8.9, 23.4, 23.3, 12.9, 28.5, 13.8, 20.9, 15.1, 27.7, 32.2, 20.4, 28.4, 3.2, 23.3, 27.8, 20.8, 28.6, 17.9, 18.6, 23.6, 12.6, 14.4, 4.8, 16.1, 24.4, 21.0, 32.8, 14.2, 27.2, 30.8, 24.0, 27.5, 31.4, 15.2, 20.7, 22.8, 26.7, 28.3, 31.1, 21.2, 27.6, 24.1, 29.5, 32.5, 12.6, 19.7, 8.0, 32.4, 29.4, 24.4, 16.1, 29.9, 23.7, 21.4, 23.2, 34.4, 15.6, 34.8, 12.0, 20.6, 16.8, 15.1, 17.8, 21.9, 34.7, 34.1, 11.3, 24.5, 23.0, 10.8, 12.4, 1.5, 28.0, 30.4, 23.4, 22.0, 37.1, 8.3, 21.0, 28.7, 20.4, 10.5, 32.1, 24.9, 26.1, 9.1, 30.3, 27.2, 15.5, 27.2, 27.7, 22.8, 18.0, 31.2, 22.6, 33.7, 34.0, 34.6, 33.4, 5.8, 12
9, 8.9, 11.3, 9.7, 11.0, 8.2, 3.9, 10.4, 3.1, 4.0, 1.5, 5.5, 10.9, 9.7, 16.4, 6.3, 9.2, 12.0, 8.9, 11.5, 17.7, 3.6, 8.0, 9.4, 8.9, 8.6, 13.5, 8.5, 14.1, 10.5, 12.7, 14.3, 3.7, 8.3, 1.0, 21.5, 12.7, 9.5, 4.2, 15.0, 9.0, 6.1, 10.2, 23.1, 7.1, 23.4, 4.3, 6.6, 5.5, 5.3, 5.7, 6.0, 15.0, 19.7, 4.9, 8.3, 8.9, 4.1, 3.4, 1.0, 13.7, 13.6, 8.0, 7.6, 27.1, 3.7, 8.0, 22.0, 6.4, 3.5, 16.5, 11.4, 11.6, 3.8, 11.4, 10.2, 5.6, 13.1, 11.6, 9.0, 7.1, 15.3, 8.1, 15.2, 17.4, 17.9, 18.6, 1.6, 6.7, 9.7, 13.3, 10.0, 11.4, 16.7, 10.2, 3.7, 7.5, 6.6, 8.8, 9.3, 9.8, 8.1, 13.2, 21.5, 2.0, 12.1, 23.0, 7.3, 8.7, 11.1, 12.3, 7.6, 7.5, 6.6, 14.6, 7.9, 7.7, 3.0, 15.6, 7.9, 6.9, 6.9, 4.4, 12.0, 11.6, 3.2, 6.2, 14.9, 7.4, 10.2, 7.4, 13.0, 14.2, 17.4, 2.5, 12.1, 12.6, 11.0, 12.0, 12.2, 22.0, 3.7, 10.8, 1.3, 12.4, 27.2, 15.7, 12.6, 14.1, 6.2, 7.2, 1.8, 8.0, 16.0, 7.0, 11.0, 7.2, 4.4, 4.4, 9.4, 7.0, 10.0, 11.7, 7.6, 9.1, 6.7, 9.9, 5.8, 16.1, 8.7, 9.1, 5.5, 14.0, 12.7, 1.6, 10.0, 10.7, 7.2, 16.3, 5.5, 6.7, 2.0, 23.1, 12.0, 6.5, 3.3, 17.9, 9.0, 18.3, 14.4, 0.0, 7.4, 5.1, 15.2, 6.2, 7.9, 2.0, 13.8, 6.4, 4.0, 17.2, 6.4, 0.0, 7.9, 7.5, 6.1, 9.1, 9.3, 2.4, 15.1, 9.8, 5.2, 14.2, 8.2, 20.5, 6.7, 13.7, 0.0, 7.6, 2.0, 11.2, 11.9, 3.3, 6.8, 9.0, 4.2, 6.6, 13.3, 5.4, 3.0, 7.1, 5.7, 11.3, 8.9, 9.3, 21.2, 7.5, 5.0, 5.8, 2. ...

# %% [markdown]
# ### Extra Various options to show the plot

# %% [markdown]
# #### 4.1 show inside the jupyter notebook

# %%
pyo.iplot(fig)

# %% [markdown]
# #### 4.2 show as web page

# %%
pyo.plot(fig, filename='plotly_online_webpage.html')

# %% [markdown]
# #### 4.3 Show as plotly public data
#
# Need registration at plotly cloud

# %%
import plotly.plotly as py

py.plot(fig, filename = 'Show_plotly_public')

# %% [markdown]
# #### 4.4 save as static figure
#
# Need pip install additional module
#
# conda install -c plotly plotly-orca

# %%
import plotly.io as pio
# conda install -c plotly plotly-orca
#pyo.plot(data, image_filename='xxx', image='png')

pio.write_image(fig, 'fig_export.png')
